# %%
import pandas as pd

# %%
#Session 7 Simple and Multiple Regression, logistic Regression

# %%
user_data = pd.read_csv(r"C:\Users\MuhammadBilal\OneDrive - Unison\Desktop\sales_2016.csv")

# %%
user_data
# Out:
#       Order ID Customer ID SalesPerson  Order Date Order Priority      SKU  \
# 0         2277        C236     Richard    1/1/2016  Not Specified  SKU1005
# 1         2277        C236     Richard    1/1/2016  Not Specified   SKU602
# 2        16262        C465         Bob    1/1/2016            Low   SKU552
# 3        17058        C296         Bob    1/1/2016           High   SKU647
# 4        52640        C719         Bob    1/1/2016         Medium   SKU401
# ...        ...         ...         ...         ...            ...      ...
# 1999      3271        C398     Richard  30/12/2016       Critical   SKU576
# 2000     27137        C029     Richard  30/12/2016           High  SKU1194
# 2001     37543        C248     Richard  30/12/2016         Medium   SKU768
# 2002     51648        C660         Bob  31/12/2016            Low  SKU1068
# 2003     51648        C660        John  31/12/2016            Low   SKU600
#
# ...

# %%
#Simple Linear Regression
#Sci-Kit Learn
#Statsmodels

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import statsmodels.api as sm

# %%
x = user_data.Shipping_Amount
y = user_data.Discount

x = sm.add_constant(x) #this command shows the value of constant

model = sm.OLS(y,x)  ## Ordinary Least Square
results = model.fit() ## Draws line from 3 dots
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Discount   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1687
# Date:                Wed, 29 Dec 2021   Prob (F-statistic):              0.681
# Time:                        11:43:03   Log-Likelihood:                 4056.0
# No. Observations:                2004   AIC:                            -8108.
# Df Residuals:                    2002   BIC:                            -8097.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x = user_data[['Order_Quantity','Unit_Sell_Price']]
y = user_data.Discount

x = sm.add_constant(x)

model = sm.OLS(y,x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Discount   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2923
# Date:                Wed, 29 Dec 2021   Prob (F-statistic):              0.747
# Time:                        12:11:04   Log-Likelihood:                 4056.2
# No. Observations:                2004   AIC:                            -8106.
# Df Residuals:                    2001   BIC:                            -8090.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
#Logistic Regression

import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
logistic_regression = pd.read_csv(r"C:\Users\MuhammadBilal\OneDrive - Unison\Desktop\Logisticregression.csv")

# %%
logistic_regression
# Out:
#      Order_ID  Status
# 0        2277       1
# 1        2277       0
# 2       16262       1
# 3       17058       0
# 4       52640       1
# ..        ...     ...
# 131     15106       0
# 132     24960       1
# 133     24960       0
# 134     24960       1
# 135     24960       0
#
# [136 rows x 2 columns]

# %%
logistic_regression
# Out:
#      Order_ID  Status
# 0        2277       1
# 1        2277       0
# 2       16262       1
# 3       17058       0
# 4       52640       1
# ..        ...     ...
# 131     15106       0
# 132     24960       1
# 133     24960       0
# 134     24960       1
# 135     24960       0
#
# [136 rows x 2 columns]

# %%
x = logistic_regression.Order_ID
y = logistic_regression.Status

x = sm.add_constant(x)
logistic_regression_a= sm.Logit(y,x)
logistic_regression_a = logistic_regression_a.fit()
logistic_regression_a.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.689410
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 Status   No. Observations:                  136
# Model:                          Logit   Df Residuals:                      134
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 29 Dec 2021   Pseudo R-squ.:                0.005236
# Time:                        12:38:52   Log-Likelihood:                -93.760
# converged:                       True   LL-Null:                       -94.253
# Covariance Type:            nonrobust   LLR p-value:                    0.3205
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
