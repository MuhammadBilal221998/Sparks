# %%
#session 6 
#Pandas

# %%
import pandas as pd

# %%
#Download the csv file i have mailed
#Place the file on your desktop
#Copy the path of the file
#past the path in the pd.read_csv comand as shown , write r before ""
# write \ and the file name i.e sales_2016.csv after the path of the file

# %%
user_data = pd.read_csv(r"C:\Users\MuhammadBilal\OneDrive - Unison\Desktop\sales_2016.csv")

# %%
user_data #Run the command
# Out:
#       Order ID Customer ID SalesPerson  Order Date Order Priority      SKU  \
# 0         2277        C236     Richard   1/01/2016  Not Specified  SKU1005
# 1         2277        C236     Richard   1/01/2016  Not Specified   SKU602
# 2        16262        C465         Bob   1/01/2016            Low   SKU552
# 3        17058        C296         Bob   1/01/2016           High   SKU647
# 4        52640        C719         Bob   1/01/2016         Medium   SKU401
# ...        ...         ...         ...         ...            ...      ...
# 1999      3271        C398     Richard  30/12/2016       Critical   SKU576
# 2000     27137        C029     Richard  30/12/2016           High  SKU1194
# 2001     37543        C248     Richard  30/12/2016         Medium   SKU768
# 2002     51648        C660         Bob  31/12/2016            Low  SKU1068
# 2003     51648        C660        John  31/12/2016            Low   SKU600
#
# ...

# %%
user_data.head() # this function  gives us the first 5 values
# Out:
#    Order ID Customer ID SalesPerson Order Date Order Priority      SKU  \
# 0      2277        C236     Richard  1/01/2016  Not Specified  SKU1005
# 1      2277        C236     Richard  1/01/2016  Not Specified   SKU602
# 2     16262        C465         Bob  1/01/2016            Low   SKU552
# 3     17058        C296         Bob  1/01/2016           High   SKU647
# 4     52640        C719         Bob  1/01/2016         Medium   SKU401
#
#    Order Quantity  Unit Sell Price  Discount  Shipping Amount    Ship Mode  \
# 0              10             5.98      0.01             4.38  Regular Air
# 1              21            40.99      0.06            19.99  Regular Air
# 2              11             5.18      0.06             2.04  Express Air
# 3              15             4.28      0.04             6.72  Regular Air
# 4              18            63.98      0.05            19.99  Express Air
#
#   Product Container  Ship Date
# 0        Small Pack  2/01/2016
# ...

# %%
user_data.tail()
# Out:
#       Order ID Customer ID SalesPerson  Order Date Order Priority      SKU  \
# 1999      3271        C398     Richard  30/12/2016       Critical   SKU576
# 2000     27137        C029     Richard  30/12/2016           High  SKU1194
# 2001     37543        C248     Richard  30/12/2016         Medium   SKU768
# 2002     51648        C660         Bob  31/12/2016            Low  SKU1068
# 2003     51648        C660        John  31/12/2016            Low   SKU600
#
#       Order Quantity  Unit Sell Price  Discount  Shipping Amount    Ship Mode  \
# 1999              18             8.34      0.06             1.43  Express Air
# 2000               2            35.99      0.02             1.10  Regular Air
# 2001               6            36.55      0.01            13.89  Regular Air
# 2002              45            49.99      0.03            19.99  Regular Air
# 2003              50             3.98      0.08             2.97  Regular Air
#
#      Product Container   Ship Date
# ...

# %%
user_data.columns
# Out:
# Index(['Order ID', 'Customer ID', 'SalesPerson', 'Order Date',
#        'Order Priority', 'SKU', 'Order Quantity', 'Unit Sell Price',
#        'Discount', 'Shipping Amount', 'Ship Mode', 'Product Container',
#        'Ship Date'],
#       dtype='object')

# %%
user_data.describe() #describe function gives statistical information
# Out:
#            Order ID  Order Quantity  Unit Sell Price     Discount  \
# count   2004.000000     2004.000000      2004.000000  2004.000000
# mean   30323.086327       25.777944        79.760025     0.050823
# std    17373.548594       14.412582       241.344829     0.031982
# min       32.000000        1.000000         1.260000     0.000000
# 25%    15620.500000       14.000000         6.480000     0.020000
# 50%    30017.000000       26.000000        19.980000     0.050000
# 75%    45869.000000       39.000000        85.990000     0.080000
# max    59973.000000       50.000000      6783.020000     0.160000
#
#        Shipping Amount
# count      2004.000000
# mean         12.449132
# std          17.225474
# min           0.490000
# 25%           3.140000
# 50%           5.905000
# 75%          12.520000
# max         143.710000

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2004 entries, 0 to 2003
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           2004 non-null   int64
#  1   Customer ID        2004 non-null   object
#  2   SalesPerson        2004 non-null   object
#  3   Order Date         2004 non-null   object
#  4   Order Priority     2004 non-null   object
#  5   SKU                2004 non-null   object
#  6   Order Quantity     2004 non-null   int64
#  7   Unit Sell Price    2004 non-null   float64
#  8   Discount           2004 non-null   float64
#  9   Shipping Amount    2004 non-null   float64
#  10  Ship Mode          2004 non-null   object
#  11  Product Container  2004 non-null   object
#  12  Ship Date          2004 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 203.7+ KB

# %%
user_data.Discount
# Out:
# 0       0.01
# 1       0.06
# 2       0.06
# 3       0.04
# 4       0.05
#         ...
# 1999    0.06
# 2000    0.02
# 2001    0.01
# 2002    0.03
# 2003    0.08
# Name: Discount, Length: 2004, dtype: float64

# %%
user_data.Discount.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0.01
# 1       0.06
# 2       0.06
# 3       0.04
# 4       0.05
#         ...
# 1999    0.06
# 2000    0.02
# 2001    0.01
# 2002    0.03
# 2003    0.08
# Name: Discount, Length: 2004, dtype: float64>

# %%
user_data.drop(["Discount"], axis = 1)
# Out:
#       Order ID Customer ID SalesPerson  Order Date Order Priority      SKU  \
# 0         2277        C236     Richard   1/01/2016  Not Specified  SKU1005
# 1         2277        C236     Richard   1/01/2016  Not Specified   SKU602
# 2        16262        C465         Bob   1/01/2016            Low   SKU552
# 3        17058        C296         Bob   1/01/2016           High   SKU647
# 4        52640        C719         Bob   1/01/2016         Medium   SKU401
# ...        ...         ...         ...         ...            ...      ...
# 1999      3271        C398     Richard  30/12/2016       Critical   SKU576
# 2000     27137        C029     Richard  30/12/2016           High  SKU1194
# 2001     37543        C248     Richard  30/12/2016         Medium   SKU768
# 2002     51648        C660         Bob  31/12/2016            Low  SKU1068
# 2003     51648        C660        John  31/12/2016            Low   SKU600
#
# ...

# %%
#axis 1 means to drop from coloumns

# %%
# for pandas coloumns = Axis 1
# for pandas rows = Axis 0
# index = arranging of rows the numbers per cell in rows

# %%
user_data.loc[10:15]
# Out:
#     Order ID Customer ID SalesPerson Order Date Order Priority      SKU  \
# 10     25188        C781     Richard  3/01/2016         Medium  SKU1178
# 11      4006        C355     Richard  3/01/2016         Medium   SKU580
# 12      9221        C159        John  3/01/2016            Low   SKU280
# 13      9221        C159     Richard  3/01/2016            Low   SKU496
# 14     54528        C621     Richard  4/01/2016         Medium   SKU750
# 15     54528        C621     Richard  4/01/2016         Medium   SKU829
#
#     Order Quantity  Unit Sell Price  Discount  Shipping Amount    Ship Mode  \
# 10              20            85.99      0.00             2.50  Regular Air
# 11              38            37.94      0.06             5.08  Regular Air
# 12               9             3.25      0.03            49.00  Regular Air
# 13              25            60.98      0.04            19.99  Regular Air
# 14              17            11.66      0.01             8.99  Regular Air
# ...

# %%
# loc function locates a specific row , columns , interval

# %%
user_data.loc[10:15,"SalesPerson"]
# Out:
# 10    Richard
# 11    Richard
# 12       John
# 13    Richard
# 14    Richard
# 15    Richard
# Name: SalesPerson, dtype: object
