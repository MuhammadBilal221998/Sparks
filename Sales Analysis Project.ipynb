# %%
import pandas as pd
import glob
import os

# %%
files_joined = os.path.join(r'C:\Users\MuhammadBilal\OneDrive - Unison\Desktop\d')
list_files = glob.glob(files_joined)

# %%
dataframe = pd.concat(map(pd.read_csv, list_files), ignore_index=True)
print(dataframe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e93484be8216> in <module>
# ----> 1 dataframe = pd.concat(map(pd.read_csv, list_files), ignore_index=True)
#       2 print(dataframe)
#
# NameError: name 'list_files' is not defined

# %% [markdown]
# ##Concatenating the files

# %%
path = r"C:\Users\MuhammadBilal\OneDrive - Unison\Desktop\d"
all_files = glob.glob(os.path.join(path, "*.csv"))


all_df = []
for f in all_files:
    df = pd.read_csv(f, sep=',')
    df['file'] = f.split('/')[-1]
    all_df.append(df)
    
merger_df = pd.concat(all_df, ignore_index=True, sort=True)

# %%
merger_df.to_csv("merger.csv")

# %%
pd.read_csv('merger.csv')
# Out:
#         Unnamed: 0      Order Date Order ID Price Each  \
# 0                0  04/19/19 08:46   176558      11.95
# 1                1             NaN      NaN        NaN
# 2                2  04/07/19 22:30   176559      99.99
# 3                3  04/12/19 14:38   176560        600
# 4                4  04/12/19 14:38   176560      11.99
# ...            ...             ...      ...        ...
# 186845      186845  09/17/19 20:56   259353       2.99
# 186846      186846  09/01/19 16:00   259354        700
# 186847      186847  09/23/19 07:39   259355        700
# 186848      186848  09/19/19 17:30   259356     379.99
# 186849      186849  09/30/19 00:18   259357      11.95
#
#                            Product                         Purchase Address  \
# 0             USB-C Charging Cable             917 1st St, Dallas, TX 75001
# 1                              NaN                                      NaN
# ...

# %%
all_data = pd.read_csv('merger.csv')
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 1           1             NaN      NaN        NaN                         NaN
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 1                                   NaN              NaN
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
#
#                                                 file
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...
# ...

# %%
all_data['Month'] = 3
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 1           1             NaN      NaN        NaN                         NaN
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 1                                   NaN              NaN
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
#
#                                                 file  Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      3
# ...

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 1           1             NaN      NaN        NaN                         NaN
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 1                                   NaN              NaN
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
#
#                                                 file Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...    04
# ...

# %% [markdown]
# # Clean Up the Data
# # Drop down of NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#       Unnamed: 0 Order Date Order ID Price Each Product Purchase Address  \
# 1              1        NaN      NaN        NaN     NaN              NaN
# 356          356        NaN      NaN        NaN     NaN              NaN
# 735          735        NaN      NaN        NaN     NaN              NaN
# 1433        1433        NaN      NaN        NaN     NaN              NaN
# 1553        1553        NaN      NaN        NaN     NaN              NaN
#
#      Quantity Ordered                                               file Month
# 1                 NaN  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...   NaN
# 356               NaN  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...   NaN
# 735               NaN  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...   NaN
# 1433              NaN  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...   NaN
# 1553              NaN  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...   NaN

# %%
all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 1           1             NaN      NaN        NaN                         NaN
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 1                                   NaN              NaN
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
#
#                                                 file Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...    04
# ...

# %%
all_data = all_data.dropna(how='any')
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
# 5           5  04/30/19 09:27   176561      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
# 5     333 8th St, Los Angeles, CA 90001                1
#
#                                                 file Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...    04
# ...

# %%
all_data = all_data.drop(['file'],axis=1)
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-edef38e67bec> in <module>
# ----> 1 all_data = all_data.drop(['file'],axis=1)
#       2 all_data.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
# 5           5  04/30/19 09:27   176561      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
# 5     333 8th St, Los Angeles, CA 90001                1
#
#                                                 file Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...    04
# ...

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
# 5           5  04/30/19 09:27   176561      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
# 5     333 8th St, Los Angeles, CA 90001                1
#
#                                                 file Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...    04
# ...

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID Price Each                     Product  \
# 0           0  04/19/19 08:46   176558      11.95        USB-C Charging Cable
# 2           2  04/07/19 22:30   176559      99.99  Bose SoundSport Headphones
# 3           3  04/12/19 14:38   176560        600                Google Phone
# 4           4  04/12/19 14:38   176560      11.99            Wired Headphones
# 5           5  04/30/19 09:27   176561      11.99            Wired Headphones
#
#                        Purchase Address Quantity Ordered  \
# 0          917 1st St, Dallas, TX 75001                2
# 2     682 Chestnut St, Boston, MA 02215                1
# 3  669 Spruce St, Los Angeles, CA 90001                1
# 4  669 Spruce St, Los Angeles, CA 90001                1
# 5     333 8th St, Los Angeles, CA 90001                1
#
#                                                 file  Month
# 0  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %% [markdown]
# ###Add a Sales Column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID  Price Each  \
# 0           0  04/19/19 08:46   176558       11.95
# 2           2  04/07/19 22:30   176559       99.99
# 3           3  04/12/19 14:38   176560      600.00
# 4           4  04/12/19 14:38   176560       11.99
# 5           5  04/30/19 09:27   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# 2                 1  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID  Price Each  \
# 0           0  04/19/19 08:46   176558       11.95
# 2           2  04/07/19 22:30   176559       99.99
# 3           3  04/12/19 14:38   176560      600.00
# 4           4  04/12/19 14:38   176560       11.99
# 5           5  04/30/19 09:27   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month  \
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# 2                 1  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
all_data.loc[1000]
# Out:
# Unnamed: 0                                                       1000
# Order Date                                             04/07/19 06:45
# Order ID                                                       177508
# Price Each                                                      99.99
# Product                                    Bose SoundSport Headphones
# Purchase Address             845 Lakeview St, San Francisco, CA 94016
# Quantity Ordered                                                    1
# file                C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...
# Month                                                               4
# Sales                                                           99.99
# Name: 1000, dtype: object

# %% [markdown]
# ### Question 1 : What was the best month for sales ? How much was earned that month?

# %%
results = all_data.groupby('Month').sum()

# %%
all_data['Month']
# Out:
# 0         4
# 2         4
# 3         4
# 4         4
# 5         4
#          ..
# 186845    9
# 186846    9
# 186847    9
# 186848    9
# 186849    9
# Name: Month, Length: 185950, dtype: int32

# %%
all_data['Order Date']
# Out:
# 0         04/19/19 08:46
# 2         04/07/19 22:30
# 3         04/12/19 14:38
# 4         04/12/19 14:38
# 5         04/30/19 09:27
#                ...
# 186845    09/17/19 20:56
# 186846    09/01/19 16:00
# 186847    09/23/19 07:39
# 186848    09/19/19 17:30
# 186849    09/30/19 00:18
# Name: Order Date, Length: 185950, dtype: object

# %%
all_data['Sales']
# Out:
# 0          23.90
# 2          99.99
# 3         600.00
# 4          11.99
# 5          11.99
#            ...
# 186845      8.97
# 186846    700.00
# 186847    700.00
# 186848    379.99
# 186849     11.95
# Name: Sales, Length: 185950, dtype: float64

# %%
import matplotlib.pyplot as plt
months = range(1,2)
plt.bar(months, results['Sales'])
plt.xlabel('Months')
plt.ylabel('Sales in USD($)')
plt.xticks(months)
plt.show()

# %% [markdown]
# ###Question 2 : Which City was best for Sales Figure

# %%
all_data['City'] = all_data['Purchase Address'].apply(lambda x : x.split(',')[1])
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID  Price Each  \
# 0           0  04/19/19 08:46   176558       11.95
# 2           2  04/07/19 22:30   176559       99.99
# 3           3  04/12/19 14:38   176560      600.00
# 4           4  04/12/19 14:38   176560       11.99
# 5           5  04/30/19 09:27   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month  \
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# 2                 1  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
results = all_data.groupby('City').sum()
results
# Out:
#                 Unnamed: 0    Price Each  Quantity Ordered   Month  \
# City
#  Atlanta        1389170518  2.779908e+06             16602  104794
#  Austin          924331831  1.809874e+06             11153   69829
#  Boston         1873552039  3.637410e+06             22528  141112
#  Dallas         1396143959  2.752628e+06             16730  104620
#  Los Angeles    2768528105  5.421435e+06             33289  208325
#  New York City  2314885097  4.635371e+06             27932  175741
#  Portland       1162624010  2.307747e+06             14053   87765
#  San Francisco  4164325906  8.211462e+06             50239  315520
#  Seattle        1379494712  2.733296e+06             16553  104941
#
#                        Sales
# City
#  Atlanta        2.795499e+06
#  Austin         1.819582e+06
#  Boston         3.661642e+06
#  Dallas         2.767975e+06
#  Los Angeles    5.452571e+06
#  New York City  4.664317e+06
#  Portland       2.320491e+06
#  San Francisco  8.262204e+06
# ...

# %%
cities = [city for city , df in all_data.groupby('City')]

plt.bar(cities,results['Sales'])
plt.xticks(cities, rotation='vertical', size=8)
plt.ylabel('Sales in USD($)')
plt.xlabel('City Name')
plt.show()

# %% [markdown]
# ###Question 3 : What time should we display advertisments to maximize customer's buying product

# %%
all_data.head()
# Out:
#    Unnamed: 0      Order Date Order ID  Price Each  \
# 0           0  04/19/19 08:46   176558       11.95
# 2           2  04/07/19 22:30   176559       99.99
# 3           3  04/12/19 14:38   176560      600.00
# 4           4  04/12/19 14:38   176560       11.99
# 5           5  04/30/19 09:27   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month  \
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# 2                 1  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data.head()
# Out:
#    Unnamed: 0          Order Date Order ID  Price Each  \
# 0           0 2019-04-19 08:46:00   176558       11.95
# 2           2 2019-04-07 22:30:00   176559       99.99
# 3           3 2019-04-12 14:38:00   176560      600.00
# 4           4 2019-04-12 14:38:00   176560       11.99
# 5           5 2019-04-30 09:27:00   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month  \
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute

# %%
all_data.head()
# Out:
#    Unnamed: 0          Order Date Order ID  Price Each  \
# 0           0 2019-04-19 08:46:00   176558       11.95
# 2           2 2019-04-07 22:30:00   176559       99.99
# 3           3 2019-04-12 14:38:00   176560      600.00
# 4           4 2019-04-12 14:38:00   176560       11.99
# 5           5 2019-04-30 09:27:00   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month  \
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
hours = [hour for hour , df in all_data.groupby('Hour')]

plt.plot(hours, all_data.groupby(['Hour']).count())

all_data.groupby(['Hour']).count()
plt.xticks(hours)
plt.grid()
plt.xlabel('Hour')
plt.ylabel('Number of orders')
plt.show()

# %% [markdown]
# ### Question: Most Products ordered in a pair

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]

df.head()
# Out:
#     Unnamed: 0          Order Date Order ID  Price Each  \
# 3            3 2019-04-12 14:38:00   176560      600.00
# 4            4 2019-04-12 14:38:00   176560       11.99
# 18          18 2019-04-03 19:42:00   176574      600.00
# 19          19 2019-04-03 19:42:00   176574       11.95
# 30          30 2019-04-07 11:31:00   176585       99.99
#
#                        Product                      Purchase Address  \
# 3                 Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4             Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 18                Google Phone     20 Hill St, Los Angeles, CA 90001
# 19        USB-C Charging Cable     20 Hill St, Los Angeles, CA 90001
# 30  Bose SoundSport Headphones     823 Highland St, Boston, MA 02215
#
#     Quantity Ordered                                               file  \
# 3                  1  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...
# ...

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]

df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order ID','Grouped']].drop_duplicates()
df.head()
# Out:
# <ipython-input-35-5e3ea303296e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))

count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %% [markdown]
# ###Question 5 : What product sold the most? Why do you think it sold the most?

# %%
all_data.head()
# Out:
#    Unnamed: 0          Order Date Order ID  Price Each  \
# 0           0 2019-04-19 08:46:00   176558       11.95
# 2           2 2019-04-07 22:30:00   176559       99.99
# 3           3 2019-04-12 14:38:00   176560      600.00
# 4           4 2019-04-12 14:38:00   176560       11.99
# 5           5 2019-04-30 09:27:00   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered                                               file  Month  \
# 0                 2  C:\Users\MuhammadBilal\OneDrive - Unison\Deskt...      4
# ...

# %%
all_data.drop(['file'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-2d8c0361ccd2> in <module>
# ----> 1 all_data.drop(['file'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
all_data.head()
# Out:
#    Unnamed: 0          Order Date Order ID  Price Each  \
# 0           0 2019-04-19 08:46:00   176558       11.95
# 2           2 2019-04-07 22:30:00   176559       99.99
# 3           3 2019-04-12 14:38:00   176560      600.00
# 4           4 2019-04-12 14:38:00   176560       11.99
# 5           5 2019-04-30 09:27:00   176561       11.99
#
#                       Product                      Purchase Address  \
# 0        USB-C Charging Cable          917 1st St, Dallas, TX 75001
# 2  Bose SoundSport Headphones     682 Chestnut St, Boston, MA 02215
# 3                Google Phone  669 Spruce St, Los Angeles, CA 90001
# 4            Wired Headphones  669 Spruce St, Los Angeles, CA 90001
# 5            Wired Headphones     333 8th St, Los Angeles, CA 90001
#
#    Quantity Ordered  Month   Sales          City  Hour  Minute
# 0                 2      4   23.90        Dallas     8      46
# 2                 1      4   99.99        Boston    22      30
# ...

# %%
product_group = all_data.groupby('Product')

quantity_ordered = product_group.sum()['Quantity Ordered']

products = [product for product , df in product_group]

plt.bar(products, quantity_ordered)
plt.ylabel('Quantity Ordered')
plt.xlabel('Product')
plt.xticks(products, rotation='vertical', size=8)
plt.show()

# %%
prices = all_data.groupby('Product').mean()['Price Each']

print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64
